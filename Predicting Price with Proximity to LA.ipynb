# %% [markdown]
# # <en><center>Predicting House Value</center></en>

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# ![Project pic.jpg](attachment:a1b26afa-e0c2-46d7-aaec-40e60b90035a.jpg)

# %% [markdown]
# ##  <en><center>Frantz Alexander</center></en>

# %% [markdown]
# ### <en><center>December 25, 2022</center></en>

# %% [markdown]
# #### Project Introduction

# %% [markdown]
# This is an analysis of the median house value in Los Angeles

# %% [markdown]
# ## <en><center>Libraries</center></en>

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %% [markdown]
# ## <en><center>Prepare Data</center></en>

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# Import Data

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %%
def wrangle(filepath):
    # Loading in data into a DataFrame
    df = pd.read_csv(filepath)
    
    return df

# %%
df = wrangle("California_Houses.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Median_House_Value        20640 non-null  float64
#  1   Median_Income             20640 non-null  float64
#  2   Median_Age                20640 non-null  int64
#  3   Tot_Rooms                 20640 non-null  int64
#  4   Tot_Bedrooms              20640 non-null  int64
#  5   Population                20640 non-null  int64
#  6   Households                20640 non-null  int64
#  7   Latitude                  20640 non-null  float64
#  8   Longitude                 20640 non-null  float64
#  9   Distance_to_coast         20640 non-null  float64
#  10  Distance_to_LA            20640 non-null  float64
#  11  Distance_to_SanDiego      20640 non-null  float64
#  12  Distance_to_SanJose       20640 non-null  float64
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# Median_House_Value
# Median_Income
# Median_Age
# Tot_Rooms
# Tot_Bedrooms
# Population
# Households
# Latitude
# Longitude
# Distance_to_coast
# Distance_to_LA
# Distance_to_SanDiego
# Distance_to_SanJose
# Distance_to_SanFrancisco

# %%
len(df)
# Out:
# 20640

# %% [markdown]
# Data Exploration

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %%
corr = df.corr()

# %%
plt.figure(figsize = (12,10))
sns.heatmap(
    data = corr,
    cmap = "mako",
    linewidth = 1,
    linecolor = "black"

)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Split

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# ## <en><center>Model Building</center></en>

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# ## Baseline

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# ## Iterate

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# ## Evalutate

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)

# %% [markdown]
# ## <en><center>Communication</center></en>

# %% [markdown]
# ![Mango.png](attachment:e6ab1c59-0f25-4b49-91aa-19c21e857a08.png)
